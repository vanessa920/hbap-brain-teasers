# %% [markdown]
# # Collabrative Filtering

# %% [markdown]
# Collabrative Filtering Item-Item Recommendation System

# %%
import numpy as np
import pandas as pd
from numpy import dot
from numpy.linalg import norm
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity

# %%
# HBAP Async 6.4 Collabrative Filltering Recommendation System
# Users are rows and Items are columns 
# The task is to predict the fifth user's rating on the 6th item

matrix = [[1,0,0,2,0,1],
          [0,0,2,4,0,0],
          [3,4,4,0,5,3],
          [0,3,0,1,4,0],
          [3,4,5,2,0],
          [0,2,0,0,0,5],
          [0,0,0,3,4,0],
          [2,0,4,0,0,0],
          [0,0,0,4,0,5],
          [0,0,0,3,2,0],
          [4,2,2,5,1,4],
          [0,5,0,0,3,0]]

# %%
matrix_df = pd.DataFrame(matrix)

matrix_df = matrix_df.replace(0, np.nan)

# %%
matrix_df # Original dataframe
# Out:
#       0    1    2    3    4    5
# 0   1.0  NaN  NaN  2.0  NaN  1.0
# 1   NaN  NaN  2.0  4.0  NaN  NaN
# 2   3.0  4.0  4.0  NaN  5.0  3.0
# 3   NaN  3.0  NaN  1.0  4.0  NaN
# 4   3.0  4.0  5.0  2.0  NaN  NaN
# 5   NaN  2.0  NaN  NaN  NaN  5.0
# 6   NaN  NaN  NaN  3.0  4.0  NaN
# 7   2.0  NaN  4.0  NaN  NaN  NaN
# 8   NaN  NaN  NaN  4.0  NaN  5.0
# 9   NaN  NaN  NaN  3.0  2.0  NaN
# 10  4.0  2.0  2.0  5.0  1.0  4.0
# 11  NaN  5.0  NaN  NaN  3.0  NaN

# %%
#Normalizing the matrix

df = pd.DataFrame() 

for i in range(6):
    df[i] = matrix_df[i] - matrix_df[i].mean()

df = df.replace(np.nan,0)

# %%
df #Normalized matrix
# Out:
#       0         1    2    3         4    5
# 0  -1.6  0.000000  0.0 -1.0  0.000000 -2.6
# 1   0.0  0.000000 -1.4  1.0  0.000000  0.0
# 2   0.4  0.666667  0.6  0.0  1.833333 -0.6
# 3   0.0 -0.333333  0.0 -2.0  0.833333  0.0
# 4   0.4  0.666667  1.6 -1.0  0.000000  0.0
# 5   0.0 -1.333333  0.0  0.0  0.000000  1.4
# 6   0.0  0.000000  0.0  0.0  0.833333  0.0
# 7  -0.6  0.000000  0.6  0.0  0.000000  0.0
# 8   0.0  0.000000  0.0  1.0  0.000000  1.4
# 9   0.0  0.000000  0.0  0.0 -1.166667  0.0
# 10  1.4 -1.333333 -1.4  2.0 -2.166667  0.4
# 11  0.0  1.666667  0.0  0.0 -0.166667  0.0

# %%
# Calculating cosine similarity

def sim(i,j):
    return round(dot(i, j)/(norm(i)*norm(j)),2)

# %%
# Put all the cosine similarity to lists
def sim_list(item):
    return [sim(list(df.iloc[:,i]),list(df.iloc[:,item])) for i in range(6)]

# %%
cosine_similarity_map = defaultdict(list)

for i in range(6):
    cosine_similarity_map[i] = sim_list(i)

# %%
cosine_similarity_map # item-item cosine similarity dictionary
# Out:
# defaultdict(list,
#             {0: [1.0, -0.22, -0.24, 0.51, -0.31, 0.59],
#              1: [-0.22, 1.0, 0.46, -0.28, 0.4, -0.31],
#              2: [-0.24, 0.46, 1.0, -0.62, 0.47, -0.1],
#              3: [0.51, -0.28, -0.62, 1.0, -0.53, 0.41],
#              4: [-0.31, 0.4, 0.47, -0.53, 1.0, -0.18],
#              5: [0.59, -0.31, -0.1, 0.41, -0.18, 1.0]})

# %%
def distance(item,i):
     return cosine_similarity_map[item][item]-cosine_similarity_map[item][i]

# %%
distance_map = defaultdict(list)

for i in range(6):
    distance_map[i] = [distance(i,j) for j in range(6)]

# %%
distance_map
# Out:
# defaultdict(list,
#             {0: [0.0, 1.22, 1.24, 0.49, 1.31, 0.41000000000000003],
#              1: [1.22, 0.0, 0.54, 1.28, 0.6, 1.31],
#              2: [1.24, 0.54, 0.0, 1.62, 0.53, 1.1],
#              3: [0.49, 1.28, 1.62, 0.0, 1.53, 0.5900000000000001],
#              4: [1.31, 0.6, 0.53, 1.53, 0.0, 1.18],
#              5: [0.41000000000000003,
#               1.31,
#               1.1,
#               0.5900000000000001,
#               1.18,
#               0.0]})

# %%
# index_list = []

# for i in range(6):
#     for j in range(6):
#         if distance_map[i][j]<1 & (distance_map[i][j]>0):
#             index_list.append((i,j))

# %%
# index_dict = defaultdict(list)

# for v, k in index_list:
#     index_dict[v].append(k)

# %%
def Range(list1):
    """
    Find the minimum and second minimum values in the list
    """
    min_list =[]
    lowest = list1[0]  
    lowest2 = None
    for item in list1[1:]:       
            if item < lowest:  
                lowest2 = lowest 
                lowest = item  
            elif lowest2 == None or lowest2 > item:  
                 lowest2 = item   
                    
    min_list.append(lowest)
    min_list.append(lowest2)
    return min_list

# %%
mini_distance_map = defaultdict(list)

for i in range(6):
    a = distance_map[i].copy()
    a.remove(0) # Remove the item itself (distance value = 0)
    mini_distance_map[i] = Range(a)

mini_distance_map
# Out:
# defaultdict(list,
#             {0: [0.41000000000000003, 0.49],
#              1: [0.54, 0.6],
#              2: [0.53, 0.54],
#              3: [0.49, 0.5900000000000001],
#              4: [0.53, 0.6],
#              5: [0.41000000000000003, 0.5900000000000001]})

# %%
index_map = defaultdict(list) #Find the neighbors of each item: for item 0, the similar items are item 5 and item 3

for i in range(6):
    list_index = []
    list_index.append(distance_map[i].index(mini_distance_map[i][0]))
    list_index.append(distance_map[i].index(mini_distance_map[i][1]))
    index_map[i] = list_index
index_map
# Out:
# defaultdict(list,
#             {0: [5, 3], 1: [2, 4], 2: [4, 1], 3: [0, 5], 4: [2, 1], 5: [0, 3]})

# %%
matrix_impute = matrix_df.replace(np.nan,0) 

def cal_for_rec(user, item):
    """
    Calculate certain user's item rating
    based on item-item cosine similarity
    """
    cos_list = sim_list(item)
    index_1 = index_map[item][0]
    index_2 = index_map[item][1]
    cos_1 = cos_list[index_1]
    cos_2 = cos_list[index_2]
    weight_1 = matrix_impute.iloc[user,index_1] # find the weight from pre-normalized matrix
    weight_2 = matrix_impute.iloc[user,index_2]
    return round(((cos_1*weight_1+cos_2*weight_2)/(cos_1+cos_2)),1)

# %%
cal_for_rec(4, 5) # calculating user 4 to item 5 as in the slide  (0.59*3+0.41*2)/(0.59+0.41) = (1.79+0.82)/1 = 2.61
# Out:
# 2.6

# %%
cal_for_rec(0, 1) # some values are calculated to be 0 (0.46*0 +0.4*0)/(0.46+0.4) = 0  
#Is it a problem or we can use other ways to solve?
# Out:
# 0.0

# %% [markdown]
# ## Calculate/predict all unknown ratings

# %%
dff=matrix_df.copy()

# %%
dff.iloc[i,j]=cal_for_rec(i,j) #seudo code

# %%
dff # Calculated and filled each NaN spot from the original dataframe
# Out:
#       0    1    2    3    4    5
# 0   1.0  0.0  0.0  2.0  0.0  1.0
# 1   1.9  1.1  2.0  4.0  1.1  1.6
# 2   3.0  4.0  4.0  3.0  5.0  3.0
# 3   0.5  3.0  3.5  1.0  4.0  0.4
# 4   3.0  4.0  5.0  2.0  4.5  2.6
# 5   2.7  2.0  1.0  2.2  0.9  5.0
# 6   1.4  1.9  2.0  3.0  4.0  1.2
# 7   2.0  2.1  4.0  1.1  2.2  1.2
# 8   4.5  0.0  0.0  4.0  0.0  5.0
# 9   1.4  0.9  1.0  3.0  2.0  1.2
# 10  4.0  2.0  2.0  5.0  1.0  4.0
# 11  0.0  5.0  4.0  0.0  3.0  0.0

# %%
dff_nan=dff.copy()

# %%
dff_nan=dff_nan.replace(0, np.nan) #Turn those values that cann't retrieve weights back to null, as rating 0 is not a valid value
dff_nan
# Out:
#       0    1    2    3    4    5
# 0   1.0  NaN  NaN  2.0  NaN  1.0
# 1   1.9  1.1  2.0  4.0  1.1  1.6
# 2   3.0  4.0  4.0  3.0  5.0  3.0
# 3   0.5  3.0  3.5  1.0  4.0  0.4
# 4   3.0  4.0  5.0  2.0  4.5  2.6
# 5   2.7  2.0  1.0  2.2  0.9  5.0
# 6   1.4  1.9  2.0  3.0  4.0  1.2
# 7   2.0  2.1  4.0  1.1  2.2  1.2
# 8   4.5  NaN  NaN  4.0  NaN  5.0
# 9   1.4  0.9  1.0  3.0  2.0  1.2
# 10  4.0  2.0  2.0  5.0  1.0  4.0
# 11  NaN  5.0  4.0  NaN  3.0  NaN

# %%
sum(matrix_df.isnull().sum()) # null values before
# Out:
# 37

# %%
sum(dff_nan.isnull().sum()) # null values after
# Out:
# 9

# %%
(37-9)/37 # Reduced 76% of null values
# Out:
# 0.7567567567567568

# %%
((72-9)-(72-37))/72 # Added prediction takes up 39% of total value counts
# Out:
# 0.3888888888888889

# %%
result = dff_nan.rename(columns=lambda s: "item_"+str(s+1), index=lambda s: "user_"+str(s+1))

# %%
result # Now we can predict 9 users' rating on all items
# Out:
#          item_1  item_2  item_3  item_4  item_5  item_6
# user_1      1.0     NaN     NaN     2.0     NaN     1.0
# user_2      1.9     1.1     2.0     4.0     1.1     1.6
# user_3      3.0     4.0     4.0     3.0     5.0     3.0
# user_4      0.5     3.0     3.5     1.0     4.0     0.4
# user_5      3.0     4.0     5.0     2.0     4.5     2.6
# user_6      2.7     2.0     1.0     2.2     0.9     5.0
# user_7      1.4     1.9     2.0     3.0     4.0     1.2
# user_8      2.0     2.1     4.0     1.1     2.2     1.2
# user_9      4.5     NaN     NaN     4.0     NaN     5.0
# user_10     1.4     0.9     1.0     3.0     2.0     1.2
# user_11     4.0     2.0     2.0     5.0     1.0     4.0
# user_12     NaN     5.0     4.0     NaN     3.0     NaN

# %% [markdown]
# ### Continue Calculating item-item until all the NaN values are filled

# %%
dff_nan=dff.copy()
dff_nan=dff_nan.replace(0, np.nan)
matrix_df = dff_nan

#Normalizing the matrix

df = pd.DataFrame() 

for i in range(6):
    df[i] = matrix_df[i] - matrix_df[i].mean()

df = df.replace(np.nan,0)

# Calculating cosine similarity

def sim(i,j):
    return round(dot(i, j)/(norm(i)*norm(j)),2)

# Put all the cosine similarity to lists
def sim_list(item):
    return [sim(list(df.iloc[:,i]),list(df.iloc[:,item])) for i in range(6)]  


cosine_similarity_map = defaultdict(list)

for i in range(6):
    cosine_similarity_map[i] = sim_list(i)
    
def distance(item,i):
     return cosine_similarity_map[item][item]-cosine_similarity_map[item][i]
    
distance_map = defaultdict(list)

for i in range(6):
    distance_map[i] = [distance(i,j) for j in range(6)]

def Range(list1):
    """
    Find the minimum and second minimum values in the list
    """
    min_list =[]
    lowest = list1[0]  
    lowest2 = None
    for item in list1[1:]:       
            if item < lowest:  
                lowest2 = lowest 
                lowest = item  
            elif lowest2 == None or lowest2 > item:  
                 lowest2 = item   
                    
    min_list.append(lowest)
    min_list.append(lowest2)
    return min_list

mini_distance_map = defaultdict(list)

for i in range(6):
    a = distance_map[i].copy()
    a.remove(0) # Remove the item itself (distance value = 0)
    mini_distance_map[i] = Range(a)
    
index_map = defaultdict(list)

for i in range(6):
    list_index = []
    list_index.append(distance_map[i].index(mini_distance_map[i][0]))
    list_index.append(distance_map[i].index(mini_distance_map[i][1]))
    index_map[i] = list_index
    
matrix_impute = matrix_df.replace(np.nan,0)

def cal_for_rec(user, item):
    """
    Calculate certain user's item rating
    based on item-item cosine similarity
    """
    cos_list = sim_list(item)
    index_1 = index_map[item][0]
    index_2 = index_map[item][1]
    cos_1 = cos_list[index_1]
    cos_2 = cos_list[index_2]
    weight_1 = matrix_impute.iloc[user,index_1] # find the weight from pre-normalized matrix
    weight_2 = matrix_impute.iloc[user,index_2]
    return round(((cos_1*weight_1+cos_2*weight_2)/(cos_1+cos_2)),1)

# %%
print(index_map)
# Out:
# defaultdict(<class 'list'>, {0: [5, 3], 1: [2, 4], 2: [1, 4], 3: [0, 5], 4: [2, 1], 5: [0, 3]})

# %%
cal_for_rec(11, 0) # It does not work, as the neighbors continues to be the same and the null values were not able to return weights
# Out:
# 0.0

# %% [markdown]
# ### Try User-user Approach

# %%
dff_nan=dff.copy()
dff_nan=dff_nan.replace(0, np.nan)
matrix_df = dff_nan

#Normalizing the matrix

df = pd.DataFrame() 

for i in range(6):
    df[i] = matrix_df[i] - matrix_df[i].mean()

df = df.replace(np.nan,0)

# Calculating cosine similarity

def sim(i,j):
    return round(dot(i, j)/(norm(i)*norm(j)),2)

# Put all the cosine similarity to lists
def sim_list(item):
    return [sim(list(df.iloc[i,:]),list(df.iloc[item,:])) for i in range(12)]  


cosine_similarity_map = defaultdict(list)

for i in range(12):
    cosine_similarity_map[i] = sim_list(i)
    
    
def distance(item,i):
     return cosine_similarity_map[item][item]-cosine_similarity_map[item][i]
    
distance_map = defaultdict(list)

for i in range(12):
    distance_map[i] = [distance(i,j) for j in range(12)]


def Range(list1):
    min_list =[]
    lowest = list1[0]  
    lowest2 = None
    for item in list1[1:]:       
            if item < lowest:  
                lowest2 = lowest 
                lowest = item  
            elif lowest2 == None or lowest2 > item:  
                 lowest2 = item   
                    
    min_list.append(lowest)
    min_list.append(lowest2)
    return min_list

mini_distance_map = defaultdict(list)

for i in range(12):
    a = distance_map[i].copy()
    a.remove(0)
    mini_distance_map[i] = Range(a)


index_map = defaultdict(list)

for i in range(12):
    list_index = []
    list_index.append(distance_map[i].index(mini_distance_map[i][0]))
    list_index.append(distance_map[i].index(mini_distance_map[i][1]))
    index_map[i] = list_index

matrix_impute = matrix_df.replace(np.nan,0)

def cal_for_rec(user, item):
    """
    Calculate certain user's item rating
    based on item-item cosine similarity
    """
    cos_list = sim_list(item)
    index_1 = index_map[item][0]
    index_2 = index_map[item][1]
    cos_1 = cos_list[index_1]
    cos_2 = cos_list[index_2]
    weight_1 = matrix_impute.iloc[index_1,item] # find the weight from pre-normalized matrix
    weight_2 = matrix_impute.iloc[index_2,item]
    return round(((cos_1*weight_1+cos_2*weight_2)/(cos_1+cos_2)),1)

# %%
index_map # User-user neighbors (for user 0, the closet users are user 3 and user 7)
# Out:
# defaultdict(list,
#             {0: [3, 7],
#              1: [9, 10],
#              2: [4, 11],
#              3: [0, 7],
#              4: [2, 11],
#              5: [10, 8],
#              6: [9, 0],
#              7: [0, 0],
#              8: [10, 5],
#              9: [1, 6],
#              10: [8, 5],
#              11: [4, 2]})

# %%
cal_for_rec(11, 0) # The function was able to retrieve new weights from non-null values
# Out:
# 1.1

# %%
results = dff_nan.copy()

# %%
results.iloc[11,5]=cal_for_rec(11,5) # Calculated and filled all the null value from item-item results

# %%
results
# Out:
#       0    1    2    3    4    5
# 0   1.0  1.3  4.6  2.0  4.1  1.0
# 1   1.9  1.1  2.0  4.0  1.1  1.6
# 2   3.0  4.0  4.0  3.0  5.0  3.0
# 3   0.5  3.0  3.5  1.0  4.0  0.4
# 4   3.0  4.0  5.0  2.0  4.5  2.6
# 5   2.7  2.0  1.0  2.2  0.9  5.0
# 6   1.4  1.9  2.0  3.0  4.0  1.2
# 7   2.0  2.1  4.0  1.1  2.2  1.2
# 8   4.5  1.3  4.6  4.0  4.1  5.0
# 9   1.4  0.9  1.0  3.0  2.0  1.2
# 10  4.0  2.0  2.0  5.0  1.0  4.0
# 11  1.1  5.0  4.0  1.6  3.0  4.5

# %%
results = results.rename(columns=lambda s: "item_"+str(s+1), index=lambda s: "user_"+str(s+1)) 
results 
# All the unknown results are filled. Used item-item method first to get 9 users' results and used user-user method to get the rest 3
# Out:
#          item_1  item_2  item_3  item_4  item_5  item_6
# user_1      1.0     1.3     4.6     2.0     4.1     1.0
# user_2      1.9     1.1     2.0     4.0     1.1     1.6
# user_3      3.0     4.0     4.0     3.0     5.0     3.0
# user_4      0.5     3.0     3.5     1.0     4.0     0.4
# user_5      3.0     4.0     5.0     2.0     4.5     2.6
# user_6      2.7     2.0     1.0     2.2     0.9     5.0
# user_7      1.4     1.9     2.0     3.0     4.0     1.2
# user_8      2.0     2.1     4.0     1.1     2.2     1.2
# user_9      4.5     1.3     4.6     4.0     4.1     5.0
# user_10     1.4     0.9     1.0     3.0     2.0     1.2
# user_11     4.0     2.0     2.0     5.0     1.0     4.0
# user_12     1.1     5.0     4.0     1.6     3.0     4.5
